# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Jaaziel Raighne M. Pagulayan

# %%
#2ECE-C

# %%
#09/14/2026

# %%
# A. VISAYAS COMMUNNICATION DATAFRAME

# %%
df = pd.read_excel('board2.xlsx')
df['Average'] = df[['Math', 'Electronics']].mean(axis=1)

# %%
VisComm = df.loc[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication'), ['Name', 'Gender', 'Math', 'Electronics', 'Average']]
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56     52.0
# 11  S12    Male    89           67     78.0
# 17  S18    Male    81           40     60.5
# 21  S22  Female    64           39     51.5
# 27  S28    Male    85           53     69.0

# %%
VisComm.shape[0]
# Out:
# 5

# %%
#B. VISAYAS FEMALE DATAFRAME

# %%
df['Average'] = df[['GEAS', 'Electronics']].mean(axis=1)

# %%
VisFemale = df.loc[(df['Hometown'] == 'Visayas') & (df['Gender'] == 'Female'), ['Name', 'Gender', 'GEAS', 'Electronics', 'Average']]
VisFemale
# Out:
#    Name  Gender  GEAS  Electronics  Average
# 5    S6  Female    86           45     65.5
# 10  S11  Female    48           56     52.0
# 20  S21  Female    68           51     59.5
# 21  S22  Female    89           39     64.0
# 23  S24  Female    60           45     52.5
# 25  S26  Female    83           47     65.0

# %%
VisFemale.loc[(VisFemale['Average'] >= 60)]
# Out:
#    Name  Gender  GEAS  Electronics  Average
# 5    S6  Female    86           45     65.5
# 21  S22  Female    89           39     64.0
# 25  S26  Female    83           47     65.0

# %%
#C. CATEGORY-AVERAGE VISUALIZATION

# %%
df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)

# %%
mean_track = df.groupby("Track")["Average"].mean().reset_index()
mean_gender = df.groupby("Gender")["Average"].mean().reset_index()
mean_hometown = df.groupby("Hometown")["Average"].mean().reset_index()

# %%
mean_track
# Out:
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500

# %%
mean_gender
# Out:
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333

# %%
mean_hometown
# Out:
#    Hometown    Average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.bar(mean_track['Track'], mean_track['Average'])
plt.title('Mean Average by Track')
plt.xlabel('Track')
plt.ylabel('Mean Average Grade')
plt.ylim(0, 100)

plt.subplot(1, 3, 2)
plt.bar(mean_gender['Gender'], mean_gender['Average'])
plt.title('Mean Average by Gender')
plt.xlabel('Gender')
plt.ylim(0, 100)

plt.subplot(1, 3, 3)
plt.bar(mean_hometown['Hometown'], mean_hometown['Average'])
plt.title('Mean Average by Hometown')
plt.xlabel('Hometown')
plt.ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
Track: The Communication track achieved the highest sample mean (67.97).
Gender: Male students recorded the highest sample mean (67.18).
Hometown: Students from Luzon obtained the highest sample mean (68.08).

# %%
1. Setup & Student Header
import pandas as pd: Imports the Pandas library, commonly abbreviated as pd, which is used for data manipulation, cleaning, and structured analysis using DataFrames.
import matplotlib.pyplot as plt: Imports Matplotlib’s plotting interface to generate charts and visualizations.
# Jaaziel Raighne M. Pagulayan, #2ECE-C, #09/14/2026: Python comment lines containing metadata (student name, section/class, and date) that do not execute as code.


2. Section A: Visayas Communication DataFrame
df = pd.read_excel('board2.xlsx'): Reads the dataset from an Excel file named board2.xlsx into a main DataFrame called df.
df['Average'] = df[['Math', 'Electronics']].mean(axis=1): Calculates the row-wise mean (axis=1) of the Math and Electronics columns for each student and creates a new column called Average.
VisComm = df.loc[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication'), ['Name', 'Gender', 'Math', 'Electronics', 'Average']]: Filters the main dataset for students whose Hometown is Visayas AND whose academic Track is Communication. It selects only five specific columns (Name, Gender, Math, Electronics, Average) and stores them in the variable VisComm.
VisComm: Displays the filtered VisComm DataFrame in the output.
VisComm.shape[0]: Returns the number of rows in the VisComm DataFrame (which evaluates to 5 in the output).

3. Section B: Visayas Female DataFrame
df['Average'] = df[['GEAS', 'Electronics']].mean(axis=1): Overwrites the Average column in df by computing the row-wise mean of the GEAS and Electronics columns instead.
VisFemale = df.loc[(df['Hometown'] == 'Visayas') & (df['Gender'] == 'Female'), ['Name', 'Gender', 'GEAS', 'Electronics', 'Average']]: Filters the dataset for students who are Female from Visayas, selecting the columns Name, Gender, GEAS, Electronics, and Average.
VisFemale: Displays the filtered VisFemale DataFrame in the output.
VisFemale.loc[(VisFemale['Average'] >= 60)]: Further filters VisFemale to display only the rows where the recalculated Average score is 60 or greater.

4. Section C: Category-Average Visualization
df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1): Updates the Average column a third time to calculate the overall mean grade across four subjects: Math, Electronics, GEAS, and Communication.
mean_track = df.groupby("Track")["Average"].mean().reset_index(): Groups the data by Track, computes the mean grade of the overall Average for each track, and resets the index to keep it as a clean DataFrame.
mean_gender = df.groupby("Gender")["Average"].mean().reset_index(): Groups the data by Gender and computes the mean overall average grade for each gender group.
mean_hometown = df.groupby("Hometown")["Average"].mean().reset_index(): Groups the data by Hometown and computes the mean overall average grade for each region.
mean_track, mean_gender, mean_hometown: Displays the resulting grouped summary DataFrames in sequential execution cells.

5. Matplotlib Plotting Code
plt.figure(figsize=(15, 5)): Initializes a broad canvas/figure with a width of 15 inches and a height of 5 inches.
plt.subplot(1, 3, 1): Configures a 1-row by 3-column grid of subplots and selects the first panel.
plt.bar(mean_track['Track'], mean_track['Average']): Plots a bar chart comparing the mean grades by Track.
plt.title('Mean Average by Track'): Sets the plot title.
plt.xlabel('Track') / plt.ylabel('Mean Average Grade'): Sets the x and y axis labels.
plt.ylim(0, 100): Scales the y-axis from 0 to 100.
plt.subplot(1, 3, 2): Selects the second panel in the grid.
Plots a bar chart of Mean Average by Gender with appropriate titles and y-axis limits (0–100).
plt.subplot(1, 3, 3): Selects the third panel in the grid.
Plots a bar chart of Mean Average by Hometown with appropriate titles and y-axis limits (0–100).
plt.tight_layout(): Automatically adjusts spacing between subplots to prevent overlapping text/labels.
plt.show(): Renders and displays the final 3-panel visual plot figure in the output.1. Setup & Student Header
import pandas as pd: Imports the Pandas library, commonly abbreviated as pd, which is used for data manipulation, cleaning, and structured analysis using DataFrames.
import matplotlib.pyplot as plt: Imports Matplotlib’s plotting interface to generate charts and visualizations.
# Jaaziel Raighne M. Pagulayan, #2ECE-C, #09/14/2026: Python comment lines containing metadata (student name, section/class, and date) that do not execute as code.






. Section A: Visayas Communication DataFrame
df = pd.read_excel('board2.xlsx'): Reads the dataset from an Excel file named board2.xlsx into a main DataFrame called df.
df['Average'] = df[['Math', 'Electronics']].mean(axis=1): Calculates the row-wise mean (axis=1) of the Math and Electronics columns for each student and creates a new column called Average.
VisComm = df.loc[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication'), ['Name', 'Gender', 'Math', 'Electronics', 'Average']]: Filters the main dataset for students whose Hometown is Visayas AND whose academic Track is Communication. It selects only five specific columns (Name, Gender, Math, Electronics, Average) and stores them in the variable VisComm.
VisComm: Displays the filtered VisComm DataFrame in the output.
VisComm.shape[0]: Returns the number of rows in the VisComm DataFrame (which evaluates to 5 in the output).
3. Section B: Visayas Female DataFrame
df['Average'] = df[['GEAS', 'Electronics']].mean(axis=1): Overwrites the Average column in df by computing the row-wise mean of the GEAS and Electronics columns instead.
VisFemale = df.loc[(df['Hometown'] == 'Visayas') & (df['Gender'] == 'Female'), ['Name', 'Gender', 'GEAS', 'Electronics', 'Average']]: Filters the dataset for students who are Female from Visayas, selecting the columns Name, Gender, GEAS, Electronics, and Average.
VisFemale: Displays the filtered VisFemale DataFrame in the output.
VisFemale.loc[(VisFemale['Average'] >= 60)]: Further filters VisFemale to display only the rows where the recalculated Average score is 60 or greater.
4. Section C: Category-Average Visualization
df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1): Updates the Average column a third time to calculate the overall mean grade across four subjects: Math, Electronics, GEAS, and Communication.
mean_track = df.groupby("Track")["Average"].mean().reset_index(): Groups the data by Track, computes the mean grade of the overall Average for each track, and resets the index to keep it as a clean DataFrame.
mean_gender = df.groupby("Gender")["Average"].mean().reset_index(): Groups the data by Gender and computes the mean overall average grade for each gender group.
mean_hometown = df.groupby("Hometown")["Average"].mean().reset_index(): Groups the data by Hometown and computes the mean overall average grade for each region.
mean_track, mean_gender, mean_hometown: Displays the resulting grouped summary DataFrames in sequential execution cells.
5. Matplotlib Plotting Code
plt.figure(figsize=(15, 5)): Initializes a broad canvas/figure with a width of 15 inches and a height of 5 inches.
plt.subplot(1, 3, 1): Configures a 1-row by 3-column grid of subplots and selects the first panel.
plt.bar(mean_track['Track'], mean_track['Average']): Plots a bar chart comparing the mean grades by Track.
plt.title('Mean Average by Track'): Sets the plot title.
plt.xlabel('Track') / plt.ylabel('Mean Average Grade'): Sets the x and y axis labels.
plt.ylim(0, 100): Scales the y-axis from 0 to 100.
plt.subplot(1, 3, 2): Selects the second panel in the grid.
Plots a bar chart of Mean Average by Gender with appropriate titles and y-axis limits (0–100).
plt.subplot(1, 3, 3): Selects the third panel in the grid.
Plots a bar chart of Mean Average by Hometown with appropriate titles and y-axis limits (0–100).
plt.tight_layout(): Automatically adjusts spacing between subplots to prevent overlapping text/labels.
plt.show(): Renders and displays the final 3-panel visual plot figure in the output.
